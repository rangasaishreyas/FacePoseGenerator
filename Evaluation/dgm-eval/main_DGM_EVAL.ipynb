# %% [markdown]
# ### Metrics between 100 samples and FFHQ

# %%
all_folders = [
            #"12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB",
            "12-2024_SD21_LoRA4_alphaWNone_FacePortrait_Photo_Gender_Pose_BackgroundB_100samples"
            # "01-2025_ID-Booth_ABLATION", 
            #"NonFineTuned_100_samples"
            ]

loss_exps = ["no_new_Loss", "identity_loss_TimestepWeight", "triplet_prior_loss_TimestepWeight"]
# loss_exps = ["no_new_Loss_NonFinetuned"]#
# loss_exps = ["no_new_Loss_NoPrior"]

parent_folder = "../../FR_DATASETS_Conditional" #"../../FR_DATASETS_ABLATION_Conditional"
real_parent_folder = "../../FR_DATASETS" 

real_datasets = [
                #f"{real_parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/tufts_images",
                f"{real_parent_folder}/FFHQ_512/images"
                #f"{real_parent_folder}/LFW_bench/LFW_images",
                ]

nsamples = 10000 
model = "dinov2"
# model = "clip"
# model = "mae"

# seed = 0
seeds = [0] #[7]#, 7, 42, 69]
for seed in seeds:
    output_dir = f"RESULTS_ID-Booth/100_Conditional_Seed{seed}"
    # output_dir = f"RESULTS_ID-Booth_ABLATION/face_region/100_Conditional_Seed{seed}"

    for dat0 in real_datasets: 
        for main_fold in all_folders: 
            for loss_exp in loss_exps:
                dat1 = f"{parent_folder}/{main_fold}/{loss_exp}" 
                
                # TODO ... !python Precision_Recall_Density_Coverage_FR_20240929_Inception.py $dat0 $dat1 --device cuda:0 --num-workers 2 
                # !python -m dgm_eval $dat0 $dat1 --model=$model --output_dir=$output_dir --save --nsample=$nsamples --seed=$seed  --metrics prdc vendi fd kd authpct
                print("===" * 30)
            #break
        #break

    # TODO 
# Seed 42 or 7 
# maybe even 5000 samples (or more ) (all?)
# knn larger (10?)
# Out:
# Loading Model
# Getting DataLoader for path: ../../FR_DATASETS/FFHQ_512/images
#
# Total samples:  69991
# Total dataset is 2000 larger than 10000
# Subsample it to 10000
# Loading saved representations from: RESULTS_ID-Booth/100_Conditional_Seed0
#
# Loading from: RESULTS_ID-Booth/100_Conditional_Seed0/reps_images_mae_nimage-10000_test
# No saved representations found: RESULTS_ID-Booth/100_Conditional_Seed0
#
# Calculating Representations
#
#   0%|                                                   | 0/200 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 370, in <module>
#     main()
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 326, in main
#     reps_real = compute_representations(dataloader_real, model, device, args)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 135, in compute_representations
#     repsi = get_representations(model, DL, device, normalized=False)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/representations.py", line 30, in get_representations
#     for ibatch, batch in enumerate(tqdm(DataLoader.data_loader)):
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 634, in __next__
#     data = self._next_data()
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1346, in _next_data
#     return self._process_data(data)
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1372, in _process_data
#     data.reraise()
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/_utils.py", line 644, in reraise
#     raise exception
# NameError: Caught NameError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataset.py", line 298, in __getitem__
#     return self.dataset[self.indices[idx]]
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/dataloaders.py", line 45, in __getitem__
#     img = self.transform(img)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 112, in <lambda>
#     transform=lambda x: model_transform(x))
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/models/mae.py", line 108, in transform
#     image = TF.Resize(image, 224, interpolation=InterpolationMode.BICUBIC).convert('RGB')
# NameError: name 'InterpolationMode' is not defined
#
# ==========================================================================================
# Loading Model
# Getting DataLoader for path: ../../FR_DATASETS/FFHQ_512/images
#
# Total samples:  69991
# Total dataset is 2000 larger than 10000
# Subsample it to 10000
# Loading saved representations from: RESULTS_ID-Booth/100_Conditional_Seed0
#
# Loading from: RESULTS_ID-Booth/100_Conditional_Seed0/reps_images_mae_nimage-10000_test
# No saved representations found: RESULTS_ID-Booth/100_Conditional_Seed0
#
# Calculating Representations
#
#   0%|                                                   | 0/200 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 370, in <module>
#     main()
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 326, in main
#     reps_real = compute_representations(dataloader_real, model, device, args)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 135, in compute_representations
#     repsi = get_representations(model, DL, device, normalized=False)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/representations.py", line 30, in get_representations
#     for ibatch, batch in enumerate(tqdm(DataLoader.data_loader)):
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 634, in __next__
#     data = self._next_data()
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1346, in _next_data
#     return self._process_data(data)
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataloader.py", line 1372, in _process_data
#     data.reraise()
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/_utils.py", line 644, in reraise
#     raise exception
# NameError: Caught NameError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/home/darian/miniconda3/envs/dgm-eval/lib/python3.10/site-packages/torch/utils/data/dataset.py", line 298, in __getitem__
#     return self.dataset[self.indices[idx]]
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/dataloaders.py", line 45, in __getitem__
#     img = self.transform(img)
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/__main__.py", line 112, in <lambda>
#     transform=lambda x: model_transform(x))
#   File "/home/darian/Desktop/Diffusion/ID-Booth/Evaluation/dgm-eval/dgm_eval/models/mae.py", line 108, in transform
#     image = TF.Resize(image, 224, interpolation=InterpolationMode.BICUBIC).convert('RGB')
# NameError: name 'InterpolationMode' is not defined
#
# ==========================================================================================
# Loading Model

# %% [markdown]
# ### Metrics between 21 samples and Tufts

# %%
all_folders = [
            # "12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB",
            "NonFineTuned_21_samples"
            ]

loss_exps = ["no_new_Loss", "identity_loss_TimestepWeight", "triplet_prior_loss_TimestepWeight"]
loss_exps = ["no_new_Loss_NonFinetuned"]

parent_folder = "../../FR_DATASETS_Conditional"
real_parent_folder = "../../FR_DATASETS"

real_datasets = [
                f"{real_parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/tufts_images",
                #f"{real_parent_folder}/FFHQ_512/images"
                #f"{real_parent_folder}/LFW_bench/LFW_images",
                ]

nsamples = 2500 
# seed = 0
seeds = [0]#, 7, 42, 69]
for seed in seeds:
    output_dir = f"RESULTS_ID-Booth/21_Conditional_Seed{seed}"

    for dat0 in real_datasets: 
        for main_fold in all_folders: 
            for loss_exp in loss_exps:
                dat1 = f"{parent_folder}/{main_fold}/{loss_exp}" 
                
                # TODO ... !python Precision_Recall_Density_Coverage_FR_20240929_Inception.py $dat0 $dat1 --device cuda:0 --num-workers 2 
                # !python -m dgm_eval $dat0 $dat1 --model dinov2 --output_dir=$output_dir --save --nsample=$nsamples --seed=$seed  --metrics prdc vendi fd kd authpct
                print("===" * 30)
            #break
        #break

    # TODO 
# Seed 42 or 7 
# maybe even 5000 samples (or more ) (all?)
# knn larger (10?)
# Out:
# Loading Model
# Using cache found in /home/darian/.cache/torch/hub/facebookresearch_dinov2_main
# /home/darian/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /home/darian/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# /home/darian/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:33: UserWarning: xFormers is available (Block)
#   warnings.warn("xFormers is available (Block)")
# Getting DataLoader for path: ../../FR_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/tufts_images
#
# Total samples:  2299
# Loading saved representations from: RESULTS_ID-Booth/21_Conditional_Seed0
#
# Loading from: RESULTS_ID-Booth/21_Conditional_Seed0/reps_tufts_images_dinov2_nimage-2299_test
# Getting DataLoader for path: ../../FR_DATASETS_Conditional/NonFineTuned_21_samples/no_new_Loss_NonFinetuned
#
# Total samples:  2208
# Loading saved representations from: RESULTS_ID-Booth/21_Conditional_Seed0
#
# Loading from: RESULTS_ID-Booth/21_Conditional_Seed0/reps_no_new_Loss_NonFinetuned_dinov2_nimage-2208_test
# No saved representations found: RESULTS_ID-Booth/21_Conditional_Seed0
#
# Calculating Representations
#
# 100%|███████████████████████████████████████████| 45/45 [01:04<00:00,  1.43s/it]
# Saving representations to RESULTS_ID-Booth/21_Conditional_Seed0
#
# Computing scores between reference dataset and ../../FR_DATASETS_Conditional/NonFineTuned_21_samples/no_new_Loss_NonFinetuned
#
# Computing FD
#
# Computing KD
#
# MMD: 100%|█████████████████████████| 100/100 [00:06<00:00, 15.06it/s, mean=6.89]
# Computing precision, recall, density, and coverage
#
# Num real: 2208 Num fake: 2208
# Calculating diversity score
# 100%|███████████████████████████████████████| 107/107 [00:00<00:00, 4436.53it/s]
# Computing authpct
#
# fd: 1724.96822
#
# kd_value: 6.89423
#
# kd_variance: 0.06640
#
# precision: 0.00000
#
# recall: 0.15761
#
# density: 0.00000
#
# coverage: 0.00000
#
# mean vendi per class: 9.26756
#
# std vendi per class: 0.79010
#
# authpct: 100.00000
#
# Saving scores
#
# {'run00': {'fd': 1724.9682207568007, 'kd_value': 6.894232856624083, 'kd_variance': 0.06639929407678563, 'precision': 0.0, 'recall': 0.15760869565217392, 'density': 0.0, 'coverage': 0.0, 'mean vendi per class': 9.267559468941654, 'std vendi per class': 0.7900982363022785, 'authpct': 100.0}}
# saving vendi score to RESULTS_ID-Booth/21_Conditional_Seed0/dinov2_vendi_scores_nimage-2500.csv
# ==========================================================================================

# %% [markdown]
# ### Eval between Tufts and FFHQ

# %%
# dat1 = "../../../../FACE_DATASETS/FFHQ_all_images_512x512/images"
# dat0 = "../../../../FACE_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"

# !python Precision_Recall_Density_Coverage.py $dat0 $dat1 --device cuda:0 --num-workers 2 

parent_folder = "../../ID-Booth/FR_DATASETS"

dat0 = f"{parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"
dat1 = f"{parent_folder}/FFHQ_512/images"

# !python PRDC_FR_CLIP_ID-Booth_12-2024.py $dat0 $dat1 --device cuda:0 --num-workers 2 

print("===" * 20)
dat0 = f"{parent_folder}/FFHQ_512/images"
dat1 = f"{parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"

# !python PRDC_FR_CLIP_ID-Booth_12-2024.py $dat0 $dat1 --device cuda:0 --num-workers 2
# Out:
# 2025-01-09 02:19:27.462492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-09 02:19:27.472714: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-09 02:19:27.475816: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-09 02:19:27.484278: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-09 02:19:27.972906: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Size: 336
# ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Num loaded feats: 2299
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/FFHQ_512/images.npy
# Num loaded feats: 69991
# Sample it
# Samples num. of images: 2500
# Num real: 2299 Num fake: 2500
# {'PRDC': {'precision': 0.0004, 'recall': 0.6681165724227925, 'density': 8e-05, 'coverage': 0.00043497172683775554}}
# ============================================================
# 2025-01-09 02:19:36.769441: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-09 02:19:36.779698: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-09 02:19:36.782820: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-09 02:19:36.791393: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-09 02:19:37.281066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Size: 336
# ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/FFHQ_512.npy
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/FFHQ_512.npy
# Num loaded feats: 69991
# Sample it
# Samples num. of images: 2500
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Num loaded feats: 2299
# Num real: 2500 Num fake: 2299
# {'PRDC': {'precision': 0.6681165724227925, 'recall': 0.0004, 'density': 0.4011309264897782, 'coverage': 0.2084}}

# %% [markdown]
# ### PRDC among real dataset

# %%
#dat0 = "../../../../DreamBooth/FR_DATASETS/FFHQ_all_images_512x512/images"
dat0 = "../../../../DreamBooth/FR_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"

# TODO ... fix script to use transforms and things from Precision_Recall_Density_Coverage_FR_2024_10_04_Inception_NuTransform
#!python Precision_Recall_Density_Coverage_FR_among_real_20240929_Inception.py $dat0 --device cuda:0 --num-workers 2 
# FFHQ 2500
# {'PRDC': {'precision': 0.792, 'recall': 0.7736, 'density': 1.0192, 'coverage': 0.9632}}
# Out:
# seed: 42
# /home/darian/miniconda3/envs/ml4lg_diff/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/darian/miniconda3/envs/ml4lg_diff/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Load existing features from: PRDC_FR_Features_20240929_Inception/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Num loaded feats: 2299
# 2299
# Num real: 1149 Num fake: 1150
# {'PRDC': {'precision': 0.5069565217391304, 'recall': 0.31592689295039167, 'density': 0.29095652173913045, 'coverage': 0.33855526544821585}}
# PRDC_FR_RESULTS_20240929_Inception_seed42_5knn/tufts_512_poses_1-7_all_imgs_jpg_per_ID_amongReal/images_5000.json
