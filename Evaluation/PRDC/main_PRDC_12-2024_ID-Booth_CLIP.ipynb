# %% [markdown]
# ### PRDC on FR datasets

# %%
all_folders = [
            #"12-2024_SD21_LoRA4_alphaW0.1_Face",
            #"12-2024_SD21_LoRA4_alphaW0.1_Face_Poses_Environments"
            # "12-2024_SD21_LoRA4_alphaW0.1_FINAL_HeadshotPortrait_Gender_Pose_AgePhases_Background"
            "12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB",
            #"12-2024_SD21_LoRA4_alphaW0.1_FINAL_FacePortraitPhoto_Gender_Pose_AgePhases_Expression_BackgroundB"
            ]

loss_exps = ["no_new_Loss", "identity_loss_TimestepWeight", "triplet_prior_loss_TimestepWeight"]

parent_folder = "../../ID-Booth/FR_DATASETS"

real_datasets = [
                f"{parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images",
                f"{parent_folder}/FFHQ_512/images"
                ]

for dat0 in real_datasets: 
    for main_fold in all_folders: 
        for loss_exp in loss_exps:
            dat1 = f"{parent_folder}/{main_fold}/{loss_exp}" 
            # TODO ... !python Precision_Recall_Density_Coverage_FR_20240929_Inception.py $dat0 $dat1 --device cuda:0 --num-workers 2 
            # !python PRDC_FR_CLIP_ID-Booth_12-2024.py $dat0 $dat1 --device cuda:0 --num-workers 2 
            # break
            print("===" * 30)
        #break
    # break

# TODO  
# Seed 42 or 7 
# maybe even 5000 samples (or more ) (all?)
# knn larger (10?)
# Out:
# 2025-01-16 14:03:52.435660: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:03:52.445581: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:03:52.448632: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:03:52.456691: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:03:52.947710: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 42
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:327 in <module>                                                 │
# │                                                                              │
# │   324 │   │   json.dump(result, outfile, indent=4)                           │
# │   325                                                                        │
# │   326 if __name__ == '__main__':                                             │
# │ ❱ 327 │   main()                                                             │
# │   328                                                                        │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:313 in main                                                     │
# │                                                                              │
# │   310 │   set_all_seeds(seed)                                                │
# │   311 │                                                                      │
# │   312 │   feature_save_folder = f"../CMMD/CMMD_FR_Features_12-2024"# PRDC_ID │
# │ ❱ 313 │   prdc_values = calculate_scores(args.path, args.batch_size, device, │
# │   314 │                                                                      │
# │   315 │   result = {"PRDC": prdc_values}                                     │
# │   316 │   print(result)                                                      │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:261 in calculate_scores                                         │
# │                                                                              │
# │   258 │   """Calculates Precision, Recall, Coverage and Density of two paths │
# │   259 │   for p in paths:                                                    │
# │   260 │   │   if not os.path.exists(p):                                      │
# │ ❱ 261 │   │   │   raise RuntimeError('Invalid path: %s' % p)                 │
# │   262 │                                                                      │
# │   263 │   # imagenet_model = torchvision.models.vgg16(weights='IMAGENET1K_V1 │
# │   264                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Invalid path:
# ../../ID-Booth/FR_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images
# ==========================================================================================
# 2025-01-16 14:03:55.696525: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:03:55.706607: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:03:55.709691: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:03:55.717845: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:03:56.241245: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 42
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:327 in <module>                                                 │
# │                                                                              │
# │   324 │   │   json.dump(result, outfile, indent=4)                           │
# │   325                                                                        │
# │   326 if __name__ == '__main__':                                             │
# │ ❱ 327 │   main()                                                             │
# │   328                                                                        │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:313 in main                                                     │
# │                                                                              │
# │   310 │   set_all_seeds(seed)                                                │
# │   311 │                                                                      │
# │   312 │   feature_save_folder = f"../CMMD/CMMD_FR_Features_12-2024"# PRDC_ID │
# │ ❱ 313 │   prdc_values = calculate_scores(args.path, args.batch_size, device, │
# │   314 │                                                                      │
# │   315 │   result = {"PRDC": prdc_values}                                     │
# │   316 │   print(result)                                                      │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:261 in calculate_scores                                         │
# │                                                                              │
# │   258 │   """Calculates Precision, Recall, Coverage and Density of two paths │
# │   259 │   for p in paths:                                                    │
# │   260 │   │   if not os.path.exists(p):                                      │
# │ ❱ 261 │   │   │   raise RuntimeError('Invalid path: %s' % p)                 │
# │   262 │                                                                      │
# │   263 │   # imagenet_model = torchvision.models.vgg16(weights='IMAGENET1K_V1 │
# │   264                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Invalid path:
# ../../ID-Booth/FR_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images
# ==========================================================================================
# 2025-01-16 14:03:58.998773: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:03:59.011103: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:03:59.014186: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:03:59.022353: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:03:59.534204: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 42
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:327 in <module>                                                 │
# │                                                                              │
# │   324 │   │   json.dump(result, outfile, indent=4)                           │
# │   325                                                                        │
# │   326 if __name__ == '__main__':                                             │
# │ ❱ 327 │   main()                                                             │
# │   328                                                                        │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:313 in main                                                     │
# │                                                                              │
# │   310 │   set_all_seeds(seed)                                                │
# │   311 │                                                                      │
# │   312 │   feature_save_folder = f"../CMMD/CMMD_FR_Features_12-2024"# PRDC_ID │
# │ ❱ 313 │   prdc_values = calculate_scores(args.path, args.batch_size, device, │
# │   314 │                                                                      │
# │   315 │   result = {"PRDC": prdc_values}                                     │
# │   316 │   print(result)                                                      │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:261 in calculate_scores                                         │
# │                                                                              │
# │   258 │   """Calculates Precision, Recall, Coverage and Density of two paths │
# │   259 │   for p in paths:                                                    │
# │   260 │   │   if not os.path.exists(p):                                      │
# │ ❱ 261 │   │   │   raise RuntimeError('Invalid path: %s' % p)                 │
# │   262 │                                                                      │
# │   263 │   # imagenet_model = torchvision.models.vgg16(weights='IMAGENET1K_V1 │
# │   264                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Invalid path:
# ../../ID-Booth/FR_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images
# ==========================================================================================
# 2025-01-16 14:04:02.285283: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:04:02.295412: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:04:02.298493: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:04:02.306602: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:04:02.801274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 42
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:327 in <module>                                                 │
# │                                                                              │
# │   324 │   │   json.dump(result, outfile, indent=4)                           │
# │   325                                                                        │
# │   326 if __name__ == '__main__':                                             │
# │ ❱ 327 │   main()                                                             │
# │   328                                                                        │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:313 in main                                                     │
# │                                                                              │
# │   310 │   set_all_seeds(seed)                                                │
# │   311 │                                                                      │
# │   312 │   feature_save_folder = f"../CMMD/CMMD_FR_Features_12-2024"# PRDC_ID │
# │ ❱ 313 │   prdc_values = calculate_scores(args.path, args.batch_size, device, │
# │   314 │                                                                      │
# │   315 │   result = {"PRDC": prdc_values}                                     │
# │   316 │   print(result)                                                      │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:261 in calculate_scores                                         │
# │                                                                              │
# │   258 │   """Calculates Precision, Recall, Coverage and Density of two paths │
# │   259 │   for p in paths:                                                    │
# │   260 │   │   if not os.path.exists(p):                                      │
# │ ❱ 261 │   │   │   raise RuntimeError('Invalid path: %s' % p)                 │
# │   262 │                                                                      │
# │   263 │   # imagenet_model = torchvision.models.vgg16(weights='IMAGENET1K_V1 │
# │   264                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Invalid path: ../../ID-Booth/FR_DATASETS/FFHQ_512/images
# ==========================================================================================
# 2025-01-16 14:04:05.583763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:04:05.593756: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:04:05.596787: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:04:05.604930: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:04:06.113430: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 42
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:327 in <module>                                                 │
# │                                                                              │
# │   324 │   │   json.dump(result, outfile, indent=4)                           │
# │   325                                                                        │
# │   326 if __name__ == '__main__':                                             │
# │ ❱ 327 │   main()                                                             │
# │   328                                                                        │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:313 in main                                                     │
# │                                                                              │
# │   310 │   set_all_seeds(seed)                                                │
# │   311 │                                                                      │
# │   312 │   feature_save_folder = f"../CMMD/CMMD_FR_Features_12-2024"# PRDC_ID │
# │ ❱ 313 │   prdc_values = calculate_scores(args.path, args.batch_size, device, │
# │   314 │                                                                      │
# │   315 │   result = {"PRDC": prdc_values}                                     │
# │   316 │   print(result)                                                      │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:261 in calculate_scores                                         │
# │                                                                              │
# │   258 │   """Calculates Precision, Recall, Coverage and Density of two paths │
# │   259 │   for p in paths:                                                    │
# │   260 │   │   if not os.path.exists(p):                                      │
# │ ❱ 261 │   │   │   raise RuntimeError('Invalid path: %s' % p)                 │
# │   262 │                                                                      │
# │   263 │   # imagenet_model = torchvision.models.vgg16(weights='IMAGENET1K_V1 │
# │   264                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Invalid path: ../../ID-Booth/FR_DATASETS/FFHQ_512/images
# ==========================================================================================
# 2025-01-16 14:04:08.866226: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:04:08.876493: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:04:08.879648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:04:08.887892: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:04:09.389414: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 42
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:327 in <module>                                                 │
# │                                                                              │
# │   324 │   │   json.dump(result, outfile, indent=4)                           │
# │   325                                                                        │
# │   326 if __name__ == '__main__':                                             │
# │ ❱ 327 │   main()                                                             │
# │   328                                                                        │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:313 in main                                                     │
# │                                                                              │
# │   310 │   set_all_seeds(seed)                                                │
# │   311 │                                                                      │
# │   312 │   feature_save_folder = f"../CMMD/CMMD_FR_Features_12-2024"# PRDC_ID │
# │ ❱ 313 │   prdc_values = calculate_scores(args.path, args.batch_size, device, │
# │   314 │                                                                      │
# │   315 │   result = {"PRDC": prdc_values}                                     │
# │   316 │   print(result)                                                      │
# │                                                                              │
# │ /home/darian/Desktop/Diffusion/ID-Booth/Evaluation/PRDC/PRDC_FR_CLIP_ID-Boot │
# │ h_12-2024.py:261 in calculate_scores                                         │
# │                                                                              │
# │   258 │   """Calculates Precision, Recall, Coverage and Density of two paths │
# │   259 │   for p in paths:                                                    │
# │   260 │   │   if not os.path.exists(p):                                      │
# │ ❱ 261 │   │   │   raise RuntimeError('Invalid path: %s' % p)                 │
# │   262 │                                                                      │
# │   263 │   # imagenet_model = torchvision.models.vgg16(weights='IMAGENET1K_V1 │
# │   264                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Invalid path: ../../ID-Booth/FR_DATASETS/FFHQ_512/images
# ==========================================================================================

# %% [markdown]
# ### PRDC on non-FR datasets

# %%
all_folders = [
            #"12-2024_SD21_LoRA4_alphaW0.1_Face",
            #"12-2024_SD21_LoRA4_alphaW0.1_Face_Poses_Environments"
            # "12-2024_SD21_LoRA4_alphaW0.1_FINAL_HeadshotPortrait_Gender_Pose_AgePhases_Background"
            "12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB",
            #"12-2024_SD21_LoRA4_alphaW0.1_FINAL_FacePortraitPhoto_Gender_Pose_AgePhases_Expression_BackgroundB"
            ]

loss_exps = ["no_new_Loss", "identity_loss_TimestepWeight", "triplet_prior_loss_TimestepWeight"]

parent_folder = "../../ID-Booth/GENERATED_SAMPLES"

real_datasets = [
                f"{parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images",
                f"{parent_folder}/FFHQ_512/images"
                ]

for dat0 in real_datasets: 
    for main_fold in all_folders: 
        for loss_exp in loss_exps:
            dat1 = f"{parent_folder}/{main_fold}/{loss_exp}" 
            # TODO ... !python Precision_Recall_Density_Coverage_FR_20240929_Inception.py $dat0 $dat1 --device cuda:0 --num-workers 2 
            # !python PRDC_nonFR_CLIP_ID-Booth_12-2024.py $dat0 $dat1 --device cuda:0 --num-workers 2 
            #break
            print("===" * 30)
        #break
    #break
# Out:
# 2025-01-16 14:00:38.256854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:00:38.267034: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:00:38.270154: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:00:38.278358: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:00:38.780824: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images
# Check if features exist
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss
# Check if features exist
# Size: 336
# Presaved real path: ../CMMD/CMMD_NonFR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Num loaded feats: 2299
# Presaved synth path: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss.npy
# Num loaded feats: 2247
# Num real: 2299 Num fake: 2247
# {'PRDC': {'precision': 0.006675567423230975, 'recall': 0.9173553719008265, 'density': 0.0019581664441477528, 'coverage': 0.008264462809917356}}
# Save results to: PRDC_ID-Booth_NonFR_CLIP_RESULTS/12-2024_CLIP_seed7_2500/tufts_512_poses_1-7_all_imgs_jpg_per_ID_vs_12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss.json
# ==========================================================================================
# 2025-01-16 14:00:46.021624: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:00:46.031777: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:00:46.034854: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:00:46.043052: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:00:46.550223: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images
# Check if features exist
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight
# Check if features exist
# Size: 336
# Presaved real path: ../CMMD/CMMD_NonFR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Num loaded feats: 2299
# Presaved synth path: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight.npy
# Num loaded feats: 2247
# Num real: 2299 Num fake: 2247
# {'PRDC': {'precision': 0.0008900756564307966, 'recall': 0.9317094388864724, 'density': 0.000267022696929239, 'coverage': 0.0013049151805132667}}
# Save results to: PRDC_ID-Booth_NonFR_CLIP_RESULTS/12-2024_CLIP_seed7_2500/tufts_512_poses_1-7_all_imgs_jpg_per_ID_vs_12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight.json
# ==========================================================================================
# 2025-01-16 14:00:53.553525: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:00:53.563733: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:00:53.566829: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:00:53.575059: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:00:54.084925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images
# Check if features exist
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight
# Check if features exist
# Size: 336
# Presaved real path: ../CMMD/CMMD_NonFR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Num loaded feats: 2299
# Presaved synth path: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight.npy
# Num loaded feats: 2247
# Num real: 2299 Num fake: 2247
# {'PRDC': {'precision': 0.0004450378282153983, 'recall': 0.9204001739886908, 'density': 8.900756564307967e-05, 'coverage': 0.00043497172683775554}}
# Save results to: PRDC_ID-Booth_NonFR_CLIP_RESULTS/12-2024_CLIP_seed7_2500/tufts_512_poses_1-7_all_imgs_jpg_per_ID_vs_12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight.json
# ==========================================================================================
# 2025-01-16 14:01:01.070239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:01:01.080468: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:01:01.083610: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:01:01.091802: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:01:01.590734: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/FFHQ_512/images
# Check if features exist
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss
# Check if features exist
# Size: 336
# Presaved real path: ../CMMD/CMMD_NonFR_Features_12-2024/FFHQ_512/images.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/FFHQ_512/images.npy
# Num loaded feats: 70000
# Sample it
# Samples num. of images: 2500
# Presaved synth path: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss.npy
# Num loaded feats: 2247
# Num real: 2500 Num fake: 2247
# {'PRDC': {'precision': 0.25322652425456166, 'recall': 0.0032, 'density': 0.06791277258566979, 'coverage': 0.0584}}
# Save results to: PRDC_ID-Booth_NonFR_CLIP_RESULTS/12-2024_CLIP_seed7_2500/FFHQ_512_vs_12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/no_new_Loss.json
# ==========================================================================================
# 2025-01-16 14:01:10.461066: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:01:10.471229: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:01:10.474331: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:01:10.482640: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:01:10.991168: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/FFHQ_512/images
# Check if features exist
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight
# Check if features exist
# Size: 336
# Presaved real path: ../CMMD/CMMD_NonFR_Features_12-2024/FFHQ_512/images.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/FFHQ_512/images.npy
# Num loaded feats: 70000
# Sample it
# Samples num. of images: 2500
# Presaved synth path: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight.npy
# Num loaded feats: 2247
# Num real: 2500 Num fake: 2247
# {'PRDC': {'precision': 0.2113929684023142, 'recall': 0.0108, 'density': 0.05634178905206943, 'coverage': 0.0524}}
# Save results to: PRDC_ID-Booth_NonFR_CLIP_RESULTS/12-2024_CLIP_seed7_2500/FFHQ_512_vs_12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/identity_loss_TimestepWeight.json
# ==========================================================================================
# 2025-01-16 14:01:20.331453: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-16 14:01:20.341539: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-16 14:01:20.344657: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-16 14:01:20.352816: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-16 14:01:20.871648: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/FFHQ_512/images
# Check if features exist
# Invalid path: ../../ID-Booth/GENERATED_SAMPLES/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight
# Check if features exist
# Size: 336
# Presaved real path: ../CMMD/CMMD_NonFR_Features_12-2024/FFHQ_512/images.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/FFHQ_512/images.npy
# Num loaded feats: 70000
# Sample it
# Samples num. of images: 2500
# Presaved synth path: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight.npy
# Load existing features from: ../CMMD/CMMD_NonFR_Features_12-2024/12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight.npy
# Num loaded feats: 2247
# Num real: 2500 Num fake: 2247
# {'PRDC': {'precision': 0.22207387627948375, 'recall': 0.022, 'density': 0.058566978193146414, 'coverage': 0.0632}}
# Save results to: PRDC_ID-Booth_NonFR_CLIP_RESULTS/12-2024_CLIP_seed7_2500/FFHQ_512_vs_12-2024_SD21_LoRA4_alphaWNone_FINAL_FacePortraitPhoto_Gender_Pose_BackgroundB/triplet_prior_loss_TimestepWeight.json
# ==========================================================================================

# %% [markdown]
# ### PRDC for baseline models (no finetuning)

# %%
all_folders = [#"SD21_pretrained_base_prompt", 
           #"SD21_pretrained_combined", 
           "SDXL_pretrained_base_prompt",
           "SDXL_pretrained_combined"
            ]

loss_exps = ["images"]

parent_folder = "../../DreamBooth/FR_DATASETS"
#dat0 = f"{parent_folder}/FFHQ_all_images_512x512/images"
#dat0 = "../../../../DreamBooth/FR_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"

real_datasets = [f"{parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images",
                f"{parent_folder}/FFHQ_all_images_512x512/images"
                ]

for dat0 in real_datasets: 
    for main_fold in all_folders: 
        for loss_exp in loss_exps:
            dat1 = f"{parent_folder}/{main_fold}/{loss_exp}" 
            # !python PRDC_FR_CLIP_ID-Booth_12-2024.py $dat0 $dat1 --device cuda:0 --num-workers 2 
            
            print("===" * 30)
# Out:
# seed: 42
# Load existing features from: PRDC_FR_Features/2024_10_04_Inception_NuTransform/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Num loaded feats: 2299
# Samples num. of images: 2299
# ../../DreamBooth/FR_DATASETS/SDXL_pretrained_base_prompt/images
# Number of images: 2141
# 100%|███████████████████████████████████████████| 43/43 [00:05<00:00,  7.34it/s]
# Samples num. of images: 2141
# Num real: 2299 Num fake: 2141
# {'PRDC': {'precision': 0.0, 'recall': 0.30100043497172685, 'density': 0.0, 'coverage': 0.0}}
# ==========================================================================================
# seed: 42
# Load existing features from: PRDC_FR_Features/2024_10_04_Inception_NuTransform/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Num loaded feats: 2299
# Samples num. of images: 2299
# ../../DreamBooth/FR_DATASETS/SDXL_pretrained_combined/images
# Number of images: 2237
# 100%|███████████████████████████████████████████| 45/45 [00:06<00:00,  7.37it/s]
# Samples num. of images: 2237
# Num real: 2299 Num fake: 2237
# {'PRDC': {'precision': 0.0, 'recall': 0.10874293170943888, 'density': 0.0, 'coverage': 0.0}}
# ==========================================================================================
# seed: 42
# Load existing features from: PRDC_FR_Features/2024_10_04_Inception_NuTransform/FFHQ_all_images_512x512.npy
# Num loaded feats: 69986
# Samples num. of images: 69986
# Samples num. of images after sampling: 2500
# Load existing features from: PRDC_FR_Features/2024_10_04_Inception_NuTransform/SDXL_pretrained_base_prompt/images.npy
# Num loaded feats: 2141
# Samples num. of images: 2141
# Num real: 2500 Num fake: 2141
# {'PRDC': {'precision': 0.24894908921064923, 'recall': 0.1364, 'density': 0.08510042036431575, 'coverage': 0.0912}}
# ==========================================================================================
# seed: 42
# Load existing features from: PRDC_FR_Features/2024_10_04_Inception_NuTransform/FFHQ_all_images_512x512.npy
# Num loaded feats: 69986
# Samples num. of images: 69986
# Samples num. of images after sampling: 2500
# Load existing features from: PRDC_FR_Features/2024_10_04_Inception_NuTransform/SDXL_pretrained_combined/images.npy
# Num loaded feats: 2237
# Samples num. of images: 2237
# Num real: 2500 Num fake: 2237
# {'PRDC': {'precision': 0.39025480554313813, 'recall': 0.1876, 'density': 0.16405900759946357, 'coverage': 0.1844}}
# ==========================================================================================

# %% [markdown]
# ### PRDC between Tufts and FFHQ

# %%
# dat1 = "../../../../FACE_DATASETS/FFHQ_all_images_512x512/images"
# dat0 = "../../../../FACE_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"

# !python Precision_Recall_Density_Coverage.py $dat0 $dat1 --device cuda:0 --num-workers 2 

parent_folder = "../../ID-Booth/FR_DATASETS"

dat0 = f"{parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"
dat1 = f"{parent_folder}/FFHQ_512/images"

# !python PRDC_FR_CLIP_ID-Booth_12-2024.py $dat0 $dat1 --device cuda:0 --num-workers 2 

print("===" * 20)
dat0 = f"{parent_folder}/FFHQ_512/images"
dat1 = f"{parent_folder}/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"

# !python PRDC_FR_CLIP_ID-Booth_12-2024.py $dat0 $dat1 --device cuda:0 --num-workers 2
# Out:
# 2025-01-09 02:19:27.462492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-09 02:19:27.472714: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-09 02:19:27.475816: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-09 02:19:27.484278: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-09 02:19:27.972906: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Size: 336
# ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Num loaded feats: 2299
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/FFHQ_512/images.npy
# Num loaded feats: 69991
# Sample it
# Samples num. of images: 2500
# Num real: 2299 Num fake: 2500
# {'PRDC': {'precision': 0.0004, 'recall': 0.6681165724227925, 'density': 8e-05, 'coverage': 0.00043497172683775554}}
# ============================================================
# 2025-01-09 02:19:36.769441: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-09 02:19:36.779698: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-09 02:19:36.782820: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-09 02:19:36.791393: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-09 02:19:37.281066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# seed: 7
# Size: 336
# ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/FFHQ_512.npy
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/FFHQ_512.npy
# Num loaded feats: 69991
# Sample it
# Samples num. of images: 2500
# Load existing features from: ../../ID-Booth/Evaluation/CMMD/CMMD_FR_Features_12-2024/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images.npy
# Num loaded feats: 2299
# Num real: 2500 Num fake: 2299
# {'PRDC': {'precision': 0.6681165724227925, 'recall': 0.0004, 'density': 0.4011309264897782, 'coverage': 0.2084}}

# %% [markdown]
# ### PRDC among real dataset

# %%
#dat0 = "../../../../DreamBooth/FR_DATASETS/FFHQ_all_images_512x512/images"
dat0 = "../../../../DreamBooth/FR_DATASETS/tufts_512_poses_1-7_all_imgs_jpg_per_ID/images"

# TODO ... fix script to use transforms and things from Precision_Recall_Density_Coverage_FR_2024_10_04_Inception_NuTransform
#!python Precision_Recall_Density_Coverage_FR_among_real_20240929_Inception.py $dat0 --device cuda:0 --num-workers 2 
# FFHQ 2500
# {'PRDC': {'precision': 0.792, 'recall': 0.7736, 'density': 1.0192, 'coverage': 0.9632}}
# Out:
# seed: 42
# /home/darian/miniconda3/envs/ml4lg_diff/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/darian/miniconda3/envs/ml4lg_diff/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Load existing features from: PRDC_FR_Features_20240929_Inception/tufts_512_poses_1-7_all_imgs_jpg_per_ID.npy
# Num loaded feats: 2299
# 2299
# Num real: 1149 Num fake: 1150
# {'PRDC': {'precision': 0.5069565217391304, 'recall': 0.31592689295039167, 'density': 0.29095652173913045, 'coverage': 0.33855526544821585}}
# PRDC_FR_RESULTS_20240929_Inception_seed42_5knn/tufts_512_poses_1-7_all_imgs_jpg_per_ID_amongReal/images_5000.json
